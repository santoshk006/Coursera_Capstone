# %% [markdown]
# <a href="https://colab.research.google.com/github/santoshk006/Coursera_Capstone/blob/master/Capstone_Week3_Q3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q3) Explore and cluster the neighborhoods in Toronto. You can decide to work with only boroughs that contain the word Toronto and then replicate the same analysis we did to the New York City data. It is up to you.
#
# Just make sure:
#
# to add enough Markdown cells to explain what you decided to do and to report any observations you make.
# to generate maps to visualize your neighborhoods and how they cluster together.
# Once you are happy with your analysis, submit a link to the new Notebook on your Github repository. (3 marks)

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import os
from sklearn.cluster import KMeans
import folium 
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors


print('Libraries imported.')
# Out:
# Libraries imported.

# %%
List_url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
source = requests.get(List_url).text

# %%
soup = BeautifulSoup(source, 'xml')
table=soup.find('table')
column_names=['Postalcode','Borough','Neighborhood']
df = pd.DataFrame(columns=column_names)

# %%
for tr_cell in table.find_all('tr'):
    row_data=[]
    for td_cell in tr_cell.find_all('td'):
        row_data.append(td_cell.text.strip())
    if len(row_data)==3:
        df.loc[len(df)] = row_data
        df.head()

# %%
#DataCleaning
df=df[df['Borough']!='Not assigned']

# %%
df.head()
# Out:
#   Postalcode           Borough                                 Neighborhood
# 2        M3A        North York                                    Parkwoods
# 3        M4A        North York                             Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5        M6A        North York             Lawrence Manor, Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
temp_df=df.groupby('Postalcode')['Neighborhood'].apply(lambda x: "%s" % ', '.join(x))
temp_df=temp_df.reset_index(drop=False)
temp_df.rename(columns={'Neighborhood':'Neighborhood_joined'},inplace=True)

# %%
df_merge = pd.merge(df, temp_df, on='Postalcode')

# %%
df_merge.drop(['Neighborhood'],axis=1,inplace=True)

# %%
df_merge.drop_duplicates(inplace=True)

# %%
df_merge.rename(columns={'Neighborhood_joined':'Neighborhood'},inplace=True)

# %%
df_merge.head()
# Out:
#   Postalcode  ...                                       Neighborhood
# 0        M3A  ...                               Parkwoods, Parkwoods
# 2        M4A  ...                 Victoria Village, Victoria Village
# 4        M5A  ...  Regent Park, Harbourfront, Regent Park, Harbou...
# 6        M6A  ...  Lawrence Manor, Lawrence Heights, Lawrence Man...
# 8        M7A  ...  Queen's Park, Ontario Provincial Government, Q...
#
# [5 rows x 3 columns]

# %%
df_merge.shape
# Out:
# (103, 3)

# %% [markdown]
# # Geocoding

# %%
def get_geocode(postal_code):
    # initialize your variable to None
    lat_lng_coords = None
    while(lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    return latitude,longitude

# %%
geo_df=pd.read_csv('http://cocl.us/Geospatial_data')

# %%
geo_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geo_df.rename(columns={'Postal Code':'Postalcode'},inplace=True)
geo_merged = pd.merge(geo_df, df_merge, on='Postalcode')

# %%
geo_merged.head()
# Out:
#   Postalcode  ...                                       Neighborhood
# 0        M1B  ...                     Malvern, Rouge, Malvern, Rouge
# 1        M1C  ...  Rouge Hill, Port Union, Highland Creek, Rouge ...
# 2        M1E  ...  Guildwood, Morningside, West Hill, Guildwood, ...
# 3        M1G  ...                                     Woburn, Woburn
# 4        M1H  ...                               Cedarbrae, Cedarbrae
#
# [5 rows x 5 columns]

# %%
geo_data=geo_merged[['Postalcode','Borough','Neighborhood','Latitude','Longitude']]
geo_data.head()
# Out:
#   Postalcode      Borough  ...   Latitude  Longitude
# 0        M1B  Scarborough  ...  43.806686 -79.194353
# 1        M1C  Scarborough  ...  43.784535 -79.160497
# 2        M1E  Scarborough  ...  43.763573 -79.188711
# 3        M1G  Scarborough  ...  43.770992 -79.216917
# 4        M1H  Scarborough  ...  43.773136 -79.239476
#
# [5 rows x 5 columns]

# %%
toronto_data=geo_data[geo_data['Borough'].str.contains("Toronto")]
toronto_data.head()
# Out:
#    Postalcode          Borough  ...   Latitude  Longitude
# 37        M4E     East Toronto  ...  43.676357 -79.293031
# 41        M4K     East Toronto  ...  43.679557 -79.352188
# 42        M4L     East Toronto  ...  43.668999 -79.315572
# 43        M4M     East Toronto  ...  43.659526 -79.340923
# 44        M4N  Central Toronto  ...  43.728020 -79.388790
#
# [5 rows x 5 columns]

# %%
CLIENT_ID = 'XFKYSSZJSJKVIHKCCJERHSMIUYYE05MBAUEJWKXTFWUQLPG2' # your Foursquare ID
CLIENT_SECRET = 'R3ZUHYOP3GQU1QGXEDGK5MMYWOB2PJ0ZS4NXNYUSLX0V41NR' # your Foursquare Secret
VERSION = '20180604'

# %%
def getNearbyVenues(names, latitudes, longitudes):
    radius=500
    LIMIT=100
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )
# Out:
# The Beaches, The Beaches
# The Danforth West, Riverdale, The Danforth West, Riverdale
# India Bazaar, The Beaches West, India Bazaar, The Beaches West
# Studio District, Studio District
# Lawrence Park, Lawrence Park
# Davisville North, Davisville North
# North Toronto West,  Lawrence Park, North Toronto West,  Lawrence Park
# Davisville, Davisville
# Moore Park, Summerhill East, Moore Park, Summerhill East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park, Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# Rosedale, Rosedale
# St. James Town, Cabbagetown, St. James Town, Cabbagetown
# Church and Wellesley, Church and Wellesley
# Regent Park, Harbourfront, Regent Park, Harbourfront
# Garden District, Ryerson, Garden District, Ryerson
# St. James Town, St. James Town
# Berczy Park, Berczy Park
# Central Bay Street, Central Bay Street
# Richmond, Adelaide, King, Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands, Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange, Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel, Commerce Court, Victoria Hotel
# Roselawn, Roselawn
# Forest Hill North & West, Forest Hill Road Park, Forest Hill North & West, Forest Hill Road Park
# The Annex, North Midtown, Yorkville, The Annex, North Midtown, Yorkville
# University of Toronto, Harbord, University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park, Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport, CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Stn A PO Boxes, Stn A PO Boxes
# First Canadian Place, Underground city, First Canadian Place, Underground city
# Christie, Christie
# Dufferin, Dovercourt Village, Dufferin, Dovercourt Village
# Little Portugal, Trinity, Little Portugal, Trinity
# Brockton, Parkdale Village, Exhibition Place, Brockton, Parkdale Village, Exhibition Place
# High Park, The Junction South, High Park, The Junction South
# Parkdale, Roncesvalles, Parkdale, Roncesvalles
# Runnymede, Swansea, Runnymede, Swansea
# Queen's Park, Ontario Provincial Government, Queen's Park, Ontario Provincial Government
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto, Business reply mail Processing Centre, South Central Letter Processing Plant Toronto

# %%
toronto_venues.head()
# Out:
#                                         Neighborhood  ...     Venue Category
# 0                           The Beaches, The Beaches  ...              Trail
# 1                           The Beaches, The Beaches  ...  Health Food Store
# 2                           The Beaches, The Beaches  ...                Pub
# 3                           The Beaches, The Beaches  ...       Neighborhood
# 4  The Danforth West, Riverdale, The Danforth Wes...  ...     Cosmetics Shop
#
# [5 rows x 7 columns]

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  ...  Venue Category
# Neighborhood                                                               ...
# Berczy Park, Berczy Park                                               57  ...              57
# Brockton, Parkdale Village, Exhibition Place, B...                     24  ...              24
# Business reply mail Processing Centre, South Ce...                     15  ...              15
# CN Tower, King and Spadina, Railway Lands, Harb...                     17  ...              17
# Central Bay Street, Central Bay Street                                 69  ...              69
# Christie, Christie                                                     17  ...              17
# Church and Wellesley, Church and Wellesley                             74  ...              74
# Commerce Court, Victoria Hotel, Commerce Court,...                    100  ...             100
# Davisville North, Davisville North                                     11  ...              11
# Davisville, Davisville                                                 34  ...              34
# Dufferin, Dovercourt Village, Dufferin, Doverco...                     15  ...              15
# First Canadian Place, Underground city, First C...                    100  ...             100
# Forest Hill North & West, Forest Hill Road Park...                      4  ...               4
# Garden District, Ryerson, Garden District, Ryerson                    100  ...             100
# Harbourfront East, Union Station, Toronto Islan...                    100  ...             100
# High Park, The Junction South, High Park, The J...                     24  ...              24
# India Bazaar, The Beaches West, India Bazaar, T...                     18  ...              18
# Kensington Market, Chinatown, Grange Park, Kens...                     65  ...              65
# Lawrence Park, Lawrence Park                                            4  ...               4
# Little Portugal, Trinity, Little Portugal, Trinity                     43  ...              43
# Moore Park, Summerhill East, Moore Park, Summer...                      4  ...               4
# North Toronto West,  Lawrence Park, North Toron...                     19  ...              19
# Parkdale, Roncesvalles, Parkdale, Roncesvalles                         14  ...              14
# Queen's Park, Ontario Provincial Government, Qu...                     30  ...              30
# Regent Park, Harbourfront, Regent Park, Harbour...                     45  ...              45
# Richmond, Adelaide, King, Richmond, Adelaide, King                     95  ...              95
# Rosedale, Rosedale                                                      4  ...               4
# Roselawn, Roselawn                                                      1  ...               1
# Runnymede, Swansea, Runnymede, Swansea                                 35  ...              35
# St. James Town, Cabbagetown, St. James Town, Ca...                     47  ...              47
# St. James Town, St. James Town                                         84  ...              84
# Stn A PO Boxes, Stn A PO Boxes                                         97  ...              97
# Studio District, Studio District                                       40  ...              40
# Summerhill West, Rathnelly, South Hill, Forest ...                     16  ...              16
# The Annex, North Midtown, Yorkville, The Annex,...                     21  ...              21
# The Beaches, The Beaches                                                4  ...               4
# The Danforth West, Riverdale, The Danforth West...                     42  ...              42
# Toronto Dominion Centre, Design Exchange, Toron...                    100  ...             100
# University of Toronto, Harbord, University of T...                     35  ...              35
#
# [39 rows x 6 columns]

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot.drop(['Neighborhood'],axis=1,inplace=True) 
toronto_onehot.insert(loc=0, column='Neighborhood', value=toronto_venues['Neighborhood'] )
toronto_onehot.shape
# Out:
# (1624, 225)

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head()
# Out:
#                                         Neighborhood  ...  Yoga Studio
# 0                           Berczy Park, Berczy Park  ...     0.000000
# 1  Brockton, Parkdale Village, Exhibition Place, ...  ...     0.041667
# 2  Business reply mail Processing Centre, South C...  ...     0.000000
# 3  CN Tower, King and Spadina, Railway Lands, Har...  ...     0.000000
# 4             Central Bay Street, Central Bay Street  ...     0.014493
#
# [5 rows x 225 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood  ... 10th Most Common Venue
# 0                           Berczy Park, Berczy Park  ...         Farmers Market
# 1  Brockton, Parkdale Village, Exhibition Place, ...  ...              Pet Store
# 2  Business reply mail Processing Centre, South C...  ...             Restaurant
# 3  CN Tower, King and Spadina, Railway Lands, Har...  ...          Boat or Ferry
# 4             Central Bay Street, Central Bay Street  ...            Salad Place
#
# [5 rows x 11 columns]

# %% [markdown]
# # Clustering of Neigbourhoods

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 2, 0, 0, 0, 2, 0, 0, 0, 0], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head()
# Out:
#    Postalcode          Borough  ... 9th Most Common Venue  10th Most Common Venue
# 37        M4E     East Toronto  ...               Dog Run     Distribution Center
# 41        M4K     East Toronto  ...                   Pub             Pizza Place
# 42        M4L     East Toronto  ...      Sushi Restaurant          Ice Cream Shop
# 43        M4M     East Toronto  ...    Seafood Restaurant          Sandwich Place
# 44        M4N  Central Toronto  ...               Dog Run     Distribution Center
#
# [5 rows x 16 columns]

# %%
neighborhoods_venues_sorted.head()
# Out:
#    Cluster Labels  ... 10th Most Common Venue
# 0               0  ...         Farmers Market
# 1               2  ...              Pet Store
# 2               0  ...             Restaurant
# 3               0  ...          Boat or Ferry
# 4               0  ...            Salad Place
#
# [5 rows x 12 columns]

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manhattan are 43.6534817, -79.3839347.

# %%
#Map:
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
